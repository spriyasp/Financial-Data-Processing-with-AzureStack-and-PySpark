# %%
# %sql
GRANT USE CATALOG ON CATALOG PT TO `account users`;
GRANT USE SCHEMA ON SCHEMA PT.dev_metadata_schema TO `account users`;
GRANT SELECT ON TABLE PT.dev_metadata_schema.tbl_parameters TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_metadata_schema.tbl_parameters TO `account users`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG PT TO `account users`;
GRANT USE SCHEMA ON SCHEMA PT.dev_bronze TO `account users`;
GRANT SELECT ON TABLE PT.dev_bronze.dim_products TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_bronze.dim_products TO `account users`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG PT TO `account users`;
GRANT USE SCHEMA ON SCHEMA PT.dev_bronze TO `account users`;
GRANT SELECT ON TABLE PT.dev_bronze.dim_tier_details TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_bronze.dim_tier_details TO `account users`;

# %%
# %sql
GRANT SELECT ON TABLE PT.dev_bronze.fact_integcosting TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_bronze.fact_integcosting TO `account users`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA PT.dev_gold TO `account users`;
GRANT SELECT ON TABLE PT.dev_gold.salesfore_projects TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_gold.salesfore_projects TO `account users`;

# %%
# %sql
GRANT SELECT ON TABLE PT.dev_gold.fx_api TO `account users`;
GRANT ALL PRIVILEGES  ON TABLE PT.dev_gold.fx_api TO `account users`;
