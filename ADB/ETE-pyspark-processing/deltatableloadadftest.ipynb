# %%
dbutils.fs.ls("abfss://landing@projecttrackingadlsdev.dfs.core.windows.net/GCP/dim_tables/products")

# %%
dbutils.fs.ls("abfss://staging@projecttrackingadlsdev.dfs.core.windows.net/")

# %%
spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "true")
