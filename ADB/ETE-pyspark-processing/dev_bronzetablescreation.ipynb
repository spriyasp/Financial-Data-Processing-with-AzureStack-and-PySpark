# %%
# %sql
create schema pt.dev_bronze;

# %%
# %sql
create or replace table pt.dev_bronze.dim_products
(
  product_id string,
  product_name string,
  units int
)
location 'abfss://bronze@projecttrackingadlsdev.dfs.core.windows.net/dim_products';

# %%
# %sql
create or replace table pt.dev_bronze.dim_tier_details
(
  tier_id string,
  tier_name string,
  feed_date string
)
location 'abfss://bronze@projecttrackingadlsdev.dfs.core.windows.net/dim_tier_details';

# %%
# %sql
show tbl_properties pt.dev_bronze.dim_products
